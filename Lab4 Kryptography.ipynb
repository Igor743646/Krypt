# %%
import matplotlib.pyplot as plt 
from matplotlib import gridspec
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
import numpy as np
np.random.seed(0)
import random
import pylab
import pickle
import os

# %%
alpha = [chr(i) for i in range(1072, 1072 + 32)]
for i in alpha:
    print(i, end=' ')
    
MAXSYMBOLS = 150000
# Out:
# а б в г д е ж з и й к л м н о п р с т у ф х ц ч ш щ ъ ы ь э ю я

# %%
def ConfMatrix(Text):
    matrix= [[0 for i in range(32)] for i in range(32)]
    
    for i in range(len(Text) - 1):
        if Text[i] == ' ': 
            continue
        if i == 0 and Text[i + 1] != ' ':
            matrix[ord(Text[i]) - 1072][ord(Text[i + 1]) - 1072] += 1
        else:
            if Text[i + 1] != ' ':
                matrix[ord(Text[i]) - 1072][ord(Text[i + 1]) - 1072] += 1
                
    return np.array(matrix)


def PlotMatrix(*matrix):
    fig, axs = plt.subplots(1, len(matrix), figsize=(19, 5))
    
    if len(matrix) == 1: axs = [axs]
    
    for i in range(len(matrix)):
        caxes = axs[i].matshow(matrix[i])
        
        xaxis = np.arange(len(alpha))
        axs[i].set_xticks(xaxis)
        axs[i].set_yticks(xaxis)
        axs[i].set_xticklabels(alpha)
        axs[i].set_yticklabels(alpha)

    fig.colorbar(caxes)
    fig.suptitle('Result')
    plt.show()
    
    
def ClearText(text):
    result = text
    result = result.lower()
    result = result.replace('ё', 'е').replace('\n', ' ').replace('\t', ' ')
    result = result.translate({ord(i) : ' ' for i in set(result) if i not in alpha})
    result = " ".join(result.split())
    return result

def MatchPercentage(t1, t2):
    
    l = min(len(t1), len(t2))
    a = sum(1 for i in range(l) if t1[i] == t2[i])
            
    return a / max(len(t1), len(t2))

def Analis(t1, t2):
    mt1, mt2 = ConfMatrix(t1), ConfMatrix(t2)
    mt1, mt2 = mt1 / mt1.max(), mt2 / mt2.max()
    print(f"Процент совпадения побуквенного анализа: {MatchPercentage(t1, t2)}")
    PlotMatrix(mt1, mt2)
    E = np.ones((32, 32), dtype=np.float64)
    m = np.maximum(np.maximum(mt1, mt2), E)
    print("Средний процент частотного совпадения пар символов: {}".format(1.0 - (np.absolute(mt1 - mt2) / m).sum() / len(alpha)**2 ))

# %% [markdown]
# Различные тексты:

# %%
file = open(os.getcwd() + '\\Тарас Бульба.txt', 'r', encoding="utf-8")
Text1 = file.read()
Text1 = ClearText(Text1)[:MAXSYMBOLS]
print("Длина текста:", len(Text1))
print(set(Text1))
file.close()
# Out:
# Длина текста: 150000
# {'ш', 'щ', 'п', 'и', 'у', 'ц', 'р', 'ы', 'о', 'с', 'в', 'ж', 'к', 'т', 'й', 'я', 'д', 'е', 'н', 'х', 'м', 'а', 'г', 'ь', 'ф', 'ъ', 'з', 'л', 'ч', 'э', ' ', 'б', 'ю'}

# %%
file = open(os.getcwd() + '\\Евгений Онегин.txt', 'r', encoding="utf-8")
Text2 = file.read()
Text2 = ClearText(Text2)[:MAXSYMBOLS]
print("Длина текста:", len(Text2))
print(set(Text2))
file.close()
# Out:
# Длина текста: 150000
# {'ш', 'щ', 'п', 'и', 'у', 'ц', 'р', 'ы', 'о', 'с', 'в', 'ж', 'к', 'т', 'й', 'я', 'д', 'е', 'н', 'х', 'м', 'а', 'г', 'ь', 'ф', 'ъ', 'з', 'л', 'ч', 'э', ' ', 'б', 'ю'}

# %%
RandText1 = ""

for i in range(MAXSYMBOLS):
    RandText1 += random.choice(alpha + [' '])
    
print("Длина текста:", len(RandText1))
print(set(RandText1))
# Out:
# Длина текста: 150000
# {'ш', 'щ', 'п', 'и', 'ц', 'у', 'р', 'ы', 'о', 'с', 'в', 'ж', 'к', 'т', 'й', 'я', 'д', 'е', 'н', 'х', 'м', 'ь', 'а', 'г', 'ф', 'ъ', 'з', 'л', 'ч', 'э', ' ', 'б', 'ю'}

# %%
RandText2 = ""

for i in range(MAXSYMBOLS):
    RandText2 += random.choice(alpha + [' '])
    
print("Длина текста:", len(RandText2))
print(set(RandText2))
# Out:
# Длина текста: 150000
# {'ш', 'щ', 'п', 'ц', 'и', 'у', 'р', 'ы', 'о', 'с', 'в', 'ж', 'к', 'т', 'й', 'я', 'д', 'е', 'н', 'х', 'м', 'а', 'г', 'ь', 'ф', 'ъ', 'з', 'л', 'ч', 'э', ' ', 'б', 'ю'}

# %%
ListOfWords = Text1.split() + Text2.split()

# %%
RandTextWord1 = ""

while len(RandTextWord1) < MAXSYMBOLS:
    RandTextWord1 += random.choice(ListOfWords) + " "

RandTextWord1 = RandTextWord1[:MAXSYMBOLS]
    
print("Длина текста:", len(RandTextWord1))
print(set(RandTextWord1))
# Out:
# Длина текста: 150000
# {'ш', 'щ', 'п', 'и', 'у', 'ц', 'р', 'ы', 'о', 'с', 'в', 'ж', 'к', 'т', 'й', 'я', 'д', 'е', 'н', 'х', 'м', 'а', 'г', 'ь', 'ф', 'ъ', 'з', 'л', 'ч', 'э', ' ', 'б', 'ю'}

# %%
RandTextWord2 = ""

while len(RandTextWord2) < MAXSYMBOLS:
    RandTextWord2 += random.choice(ListOfWords) + " "

RandTextWord2 = RandTextWord2[:MAXSYMBOLS]
    
print("Длина текста:", len(RandTextWord2))
print(set(RandTextWord2))
# Out:
# Длина текста: 150000
# {'ш', 'щ', 'п', 'и', 'у', 'ц', 'р', 'ы', 'о', 'с', 'в', 'ж', 'к', 'т', 'й', 'я', 'д', 'е', 'н', 'х', 'м', 'а', 'г', 'ь', 'ф', 'ъ', 'з', 'л', 'ч', 'э', ' ', 'б', 'ю'}

# %% [markdown]
# #### 1. Два осмысленных текста на естественном языке

# %%
Analis(Text1, Text2)
# Out:
# Процент совпадения побуквенного анализа: 0.06688
# Средний процент частотного совпадения пар символов: 0.9828088811286787

# %% [markdown]
# #### 2. Осмысленный текст и текст из случайных букв

# %%
Analis(Text1, RandText1)
# Out:
# Процент совпадения побуквенного анализа: 0.03044
# Средний процент частотного совпадения пар символов: 0.26975691147272096

# %% [markdown]
# #### 3. Осмысленный текст и текст из случайных слов

# %%
Analis(Text1, RandTextWord1)
# Out:
# Процент совпадения побуквенного анализа: 0.0647
# Средний процент частотного совпадения пар символов: 0.9877507259436782

# %% [markdown]
# #### 4. Два текста из случайных букв

# %%
Analis(RandText1, RandText2)
# Out:
# Процент совпадения побуквенного анализа: 0.030046666666666666
# Средний процент частотного совпадения пар символов: 0.9257674893465909

# %% [markdown]
# #### 5. Два текста из случайных слов

# %%
Analis(RandTextWord1, RandTextWord2)
# Out:
# Процент совпадения побуквенного анализа: 0.06499333333333333
# Средний процент частотного совпадения пар символов: 0.9955050505442958
